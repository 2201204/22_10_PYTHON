# %% [markdown]
# <a href="https://colab.research.google.com/github/2201204/22_10_PYTHON/blob/main/python_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello github")
print("hello pyhton")
# Out:
# hello github
# hello pyhton
